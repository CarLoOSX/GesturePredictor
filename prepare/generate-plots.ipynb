# %%
import pandas as pd
import os

# %%
root_dir = os.path.abspath("")
dir_data = os.path.join(root_dir, "data")
dir_plots = os.path.join(root_dir, "plots")

# %%
for filename in os.listdir(dir_data):
    if filename.endswith('.csv'):
        train = os.path.join(dir_data, filename)
        print(train)
        data = pd.read_csv(train, names=["time", "xAxis", "yAxis", "zAxis"])
        # data.head(10)
        #plot = data.plot("time", legend=None)
        plot = data.plot("time")
        #plot = data.plot("time", legend=None, cmap='gray')
        # [plot.lines[i].set_color(color) for i, color in enumerate(['red', 'blue', 'green'])]
        #plot.axis('off')
        fig = plot.get_figure()
        #fig.set_size_inches(5, 5)
        #fig.savefig(dir_plots + "/" + os.path.splitext(filename)[0] + ".png", transparent=True)
        fig.savefig(dir_plots + "/" + os.path.splitext(filename)[0] + ".png")
# Out:
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622056745686.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622216458747.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/TOP_1622217074403.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622055512961.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/CIRCLE_1622732167896.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/TOP_1622216754919.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/TOP_1622216730509.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/RIGHT_1622214243229.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/RIGHT_1622748647391.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/CIRCLE_1622216577111.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/BOTTOM_1622204130091.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/TOP_1622214020339.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/RIGHT_1622732122785.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622217114684.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/BOTTOM_1622217430799.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/RIGHT_1622216646494.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622055671702.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/RIGHT_1622752336557.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622056636864.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/TOP_1622214737018.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622055360639.csv
# /Users/carloosx/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/carloosx/Projects/GesturePredictor/prepare/data/LEFT_1622216991522.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/RIGHT_1622055521152.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/TOP_1622732125431.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/BOTTOM_1622748651404.csv
# /Users/carloosx/Projects/GesturePredictor/prepare/data/CIRCLE_1622202945474.csv
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     499     try:
# --> 500         fh = fp.fileno()
#     501         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-890387fe5339> in <module>
#      13         #fig.set_size_inches(5, 5)
#      14         #fig.savefig(dir_plots + "/" + os.path.splitext(filename)[0] + ".png", transparent=True)
# ---> 15         fig.savefig(dir_plots + "/" + os.path.splitext(filename)[0] + ".png")
#      16
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2170
#    2171         try:
# -> 2172             save_handler(self, fp, filename)
#    2173         finally:
#    2174             # do what we can to clean up
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1333         _write_multiple_frames(im, fp, chunk, rawmode)
#    1334     else:
# -> 1335         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1336
#    1337     if info:
#
# ~/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     512             else:
#     513                 while True:
# --> 514                     l, s, d = e.encode(bufsize)
#     515                     fp.write(d)
#     516                     if s:
#
# KeyboardInterrupt:

# %%
for filename in os.listdir(dir_data):
    if filename.endswith('.log'):
        base = os.path.splitext(filename)[0]
        os.rename(dir_data+"/"+filename, dir_data+"/"+base + ".csv")
